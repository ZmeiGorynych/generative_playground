# %%
import torch
from math import floor, ceil
    
def warp_matrix(x):
    a=x
    b = torch.cumsum(a,0)
    t_dim = [int(ceil(b[-1])),a.shape[0]]
    trans_mat = torch.zeros(t_dim)
    
    prev_ind =[0,0]
    for i, x in enumerate(zip(a,b)):
        ai, bi = x
        this_ind = [floor(bi),i]
        if this_ind[0] == prev_ind[0]:
            trans_mat[this_ind[0], this_ind[1]] = ai
        else: # we just crossed an integer boundary
            tmp = bi - floor(bi)
            trans_mat[this_ind[0], this_ind[1]] = tmp
            trans_mat[this_ind[0]-1, this_ind[1]] = ai -tmp
        prev_ind = this_ind

    assert( (a - trans_mat.sum(0)).abs().max() < 1e-6)
    assert((torch.ones(trans_mat.shape[0] -1) -trans_mat.sum(1)[:-1]).abs().max() <1e-6)

    return trans_mat

class WarpMatrix(torch.nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x):
        return warp_matrix(x)
    
a = torch.FloatTensor(10).uniform_()
print(a)  
trans_mat = warp_matrix(a)
print(trans_mat.sum(1))
#b = torch.autograd.Variable([a.shape[0], a.shape[0]])
# Out:
#  0.2290
#  0.4237
#  0.0629
#  0.0395
#  0.7125
#  0.4943
#  0.7146
#  0.4915
#  0.4065
#  0.8245
# [torch.FloatTensor of size 10]
#
#
#  1.0000
#  1.0000
#  1.0000
#  1.0000
#  0.3990
# [torch.FloatTensor of size 5]

# %%
# !export CUDA_HOME="/usr/local/cuda"
from warpctc_pytorch import CTCLoss
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-b7a8800452b9> in <module>()
#       1 get_ipython().system('export CUDA_HOME="/usr/local/cuda"')
# ----> 2 from warpctc_pytorch import CTCLoss
#
# /home/carnd/anaconda3/lib/python3.5/site-packages/warpctc_pytorch/__init__.py in <module>()
#       5 from torch.nn.modules.loss import _assert_no_grad
#       6 from torch.utils.ffi import _wrap_function
# ----> 7 from ._warp_ctc import lib as _lib, ffi as _ffi
#       8
#       9 __all__ = []
#
# ImportError: libwarpctc.so: cannot open shared object file: No such file or directory

# %%
from torch.autograd import Variable
class FittedWarp(torch.nn.Module):
    def __init__(self, w_shape):
        super().__init__()
        self.w = torch.nn.Parameter(torch.randn(w_shape))

    def forward(self, x):
        tmp1 = x @ self.w
        tmp = torch.nn.Sigmoid()(tmp1)
        trans_mat = warp_matrix(tmp)
        print(tmp, trans_mat)
        return trans_mat @ x
    
dim = 6
a =Variable(torch.randn([10, dim]))
warp = FittedWarp(dim)
y = warp.forward(a)
print(y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-6b084ef0746b> in <module>()
#      15 a =Variable(torch.randn([10, dim]))
#      16 warp = FittedWarp(dim)
# ---> 17 y = warp.forward(a)
#      18 print(y)
#
# <ipython-input-39-6b084ef0746b> in forward(self, x)
#       8         tmp1 = x @ self.w
#       9         tmp = torch.nn.Sigmoid()(tmp1)
# ---> 10         trans_mat = warp_matrix(tmp)
#      11         print(tmp, trans_mat)
#      12         return trans_mat @ x
#
# <ipython-input-33-a5d139469b7f> in warp_matrix(x)
#       5     a=x
#       6     b = torch.cumsum(a,0)
# ----> 7     t_dim = [int(ceil(b[-1])),a.shape[0]]
#       8     trans_mat = torch.zeros(t_dim)
#       9
#
# TypeError: must be real number, not Variable
